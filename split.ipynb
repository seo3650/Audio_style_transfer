# %% [markdown]
# # Install Spleeter

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
pip install spleeter
# Out:
# ...
#      |████████████████████████████████| 10.5MB 10.1MB/s
# ...
#      |████████████████████████████████| 184kB 54.6MB/s
# ...
#      |████████████████████████████████| 61kB 6.4MB/s
# ...
#   Created wheel for spleeter: filename=spleeter-2.0.2-cp36-none-any.whl size=49687 sha256=7c91ee0190a36fb335fc31f7488a39bc8e26daf80920fc39b69ce570287e2682
#   Stored in directory: /root/.cache/pip/wheels/43/43/16/52812aff203a46f9ee6c0614afc98307bb5941eb39c03e0727
# ...
#   Created wheel for librosa: filename=librosa-0.8.0-cp36-none-any.whl size=201375 sha256=41d65f2f889d1475ff9d413340cfe8d1c2e9b0059742daadece0fc93e715c037
#   Stored in directory: /root/.cache/pip/wheels/ee/10/1e/382bb4369e189938d5c02e06d10c651817da8d485bfd1647c9
# Successfully built spleeter librosa
# ...
#   Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Found existing installation: librosa 0.6.3
#     Uninstalling librosa-0.6.3:
#       Successfully uninstalled librosa-0.6.3
# ...

# %%
from IPython.display import Audio

# %% [markdown]
# # Separate from command line

# %%
# import subprocess
# print(subprocess.call(["spleeter", 'separate', '-i', '밤편지.wav', '-o', 'output']))

"""
Put music file path between -i and -o
"""
# !spleeter separate -i 밤편지.mp3 -o output
# Out:
# 0
# 1

# %%
# !ls output/audio_example
# Out:
# accompaniment.wav  vocals.wav

# %%
Audio('output/밤편지/vocals.wav')

# %%
Audio('output/audio_example/accompaniment.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Merge file

# %%
pip install pydub

# %%
from pydub import AudioSegment

# %%
mr_file = ""
converted_file = ""
mr = AudioSegment.from_wav(mr_file)
output = AudioSegment.from_wav(converted_file)

combined_sounds = output.overlay(mr)
# combined_sounds = combined_sounds[:50000]
combined_sounds.export("./audio_merged.wav", format="wav")
# Out:
# <_io.BufferedRandom name='./audio_merged.wav'>

# %%
Audio('audio_merged.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
